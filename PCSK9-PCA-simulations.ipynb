# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('PCSK9_PCA_merged_full_PCA_proj.csv', sep=';')

# %% [markdown]
# # Apo Simulation

# %%
apo = df.loc[0:1008]
apo_array = apo.iloc[:,1:3].to_numpy()

fig1 = px.scatter(apo_array, x=0, y=1, color = apo['Frame'], marginal_x="histogram", marginal_y="histogram")
fig1.show("png")

# %% [markdown]
# # All simulations (apo + ligand simulations)

# %%
all_sim = df.iloc[:,1:3].to_numpy()

fig2 = px.scatter(all_sim, x=0, y=1, color = df['rep'])
fig2.show("png")
